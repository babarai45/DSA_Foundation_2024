# %%
a = [4, 2, 11, 3,0,1,6,7]
for j in range(1, len(a)):
    key = a[j]
    i = j - 1
    while i >= 0 and a[i] > key:
        a[i + 1] = a[i]
        i = i - 1
    a[i + 1] = key
key
# print(a)  # This will print the sorted array
# Out:
# 7

# %%
# now a  [] is more less than 1000 elements
# a make list of 1000 unsorted elements
import random
# Generating a list of 1000 unsorted elements
# a = [random.randint(1, 1000) for _ in range(1000)]
a = [4, 2, 11, 3]
# here is to function  to show total time to run the code 
import time
start = time.time()
# a = [4, 2, 11, 3]
for j in range(1, len(a)):
    key = a[j]
    i = j - 1
    while i >= 0 and a[i] > key:
        a[i + 1] = a[i]
        i = i - 1
    a[i + 1] = key
print(a)  # This will print the sorted array
end = time.time()
print(end - start)  # This will print the total time to run the code in milliseconds
key
# Out:
# [2, 3, 4, 11]
# 0.0
# 3

# %%
import time
b= [random.randint(1, 1000) for _ in range(1000)]
b.sort()
start = time.time()

print(b)
end = time.time()
print(end - start)
# Out:
# [1, 1, 1, 2, 4, 4, 7, 9, 9, 10, 11, 11, 11, 11, 14, 16, 17, 18, 18, 18, 19, 22, 22, 23, 25, 25, 25, 25, 25, 26, 29, 29, 30, 30, 31, 31, 32, 33, 35, 35, 36, 36, 36, 37, 37, 38, 39, 39, 39, 39, 39, 41, 41, 42, 42, 43, 43, 47, 49, 49, 49, 51, 51, 52, 54, 54, 56, 56, 57, 57, 59, 60, 60, 60, 60, 60, 60, 62, 63, 65, 65, 67, 70, 71, 73, 75, 76, 77, 78, 78, 81, 81, 83, 85, 85, 87, 88, 88, 90, 91, 91, 93, 93, 94, 94, 96, 96, 97, 98, 98, 99, 99, 101, 102, 104, 105, 106, 107, 107, 108, 109, 109, 111, 111, 112, 112, 114, 115, 118, 120, 121, 123, 124, 127, 128, 128, 129, 130, 131, 133, 133, 133, 135, 137, 137, 138, 140, 140, 143, 143, 143, 145, 145, 145, 145, 146, 146, 148, 148, 150, 150, 151, 154, 154, 156, 157, 159, 160, 160, 161, 162, 164, 165, 165, 166, 166, 166, 167, 168, 168, 169, 169, 173, 175, 177, 178, 179, 179, 179, 180, 181, 182, 183, 183, 183, 183, 185, 186, 190, 191, 191, 192, 192, 193, 193, 193, 197, 198, 199, 200, 200, 201, 202, 203, 206, 206, 208, 208, 211, 211, 212, 213, 213, 215, 215, 217, 222, 223, 224, 226, 227, 228, 232, 233, 234, 235, 235, 236, 238, 239, 239, 239, 240, 245, 246, 247, 249, 251, 251, 252, 253, 253, 253, 258, 258, 259, 260, 260, 262, 263, 263, 264, 267, 269, 269, 270, 272, 272, 275, 275, 276, 278, 278, 279, 279, 281, 282, 283, 283, 283, 285, 285, 286, 288, 288, 289, 290, 290, 291, 291, 294, 294, 295, 296, 298, 299, 302, 302, 303, 303, 305, 305, 305, 305, 306, 311, 311, 311, 313, 313, 313, 314, 315, 317, 318, 319, 319, 320, 320, 322, 323, 326, 326, 327, 328, 328, 329, 330, 330, 330, 331,